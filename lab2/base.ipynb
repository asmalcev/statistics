# %%
# snippet for importing local modules
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
	sys.path.append(module_path)

# %%
import numpy as np
from utils.summary_analysis import analysis, print_analysis

SIZE = 50

dists = [
	np.random.exponential(size=SIZE, scale=1.0),
	np.random.exponential(size=SIZE, scale=1.5),
	np.random.exponential(size=SIZE, scale=0.5),
	np.random.exponential(size=SIZE, scale=1.2),
	np.random.exponential(size=SIZE, scale=0.95)
]

# %%
analyzes = map(analysis, dists)

for info in analyzes:
	print_analysis(info)
# Out:
# Количество = 50
# Среднее значение = 1.0462703109545317
# Медиана = 0.7728582456865649
# Мода = 0.30734436140619625
# Геометрическое среднее = 0.5826631604419261
# Дисперсия = 0.9374522084770496
# Стандартное отклонение = 0.9682211568009912
# Стандартное ошибка = 0.13692714913245288
# Минимальное значение = 0.006344229143351844
# Максимальное значение = 3.736958516761346
# Размах = 3.7306142876179944
# Первый квартиль = 0.2837278951369138
# Третий квартиль = 1.5036605055505723
# Межквартильный размах = 1.2199326104136585
# Ассиметрия = 1.1269608005111744
# Куртоз = 0.4906579386953296
# Коэффициент вариации = 0.9254024955727408
# Сумма = 52.31351554772658
#
# Количество = 50
# Среднее значение = 1.2333624333957673
# Медиана = 0.888579376358985
# Мода = 4.3735180667334825
# Геометрическое среднее = 0.7364237997710501
# Дисперсия = 1.5499697154882297
# Стандартное отклонение = 1.2449777971868534
# Стандартное ошибка = 0.17606644856350284
# Минимальное значение = 0.018306004028880676
# Максимальное значение = 6.368034852687236
# Размах = 6.349728848658356
# Первый квартиль = 0.2881932225244962
# Третий квартиль = 1.6370066312532112
# Межквартильный размах = 1.3488134087287151
# Ассиметрия = 2.0051803000766233
# Куртоз = 5.192235730683624
# Коэффициент вариации = 1.0094176403274306
# Сумма = 61.66812166978837
#
# Количество = 50
# Среднее значение = 0.3899688525554095
# Медиана = 0.2867611945028291
# Мода = 0.2617556965188064
# Геометрическое среднее = 0.2102120766155401
# Дисперсия = 0.10299630163228947
# Стандартное отклонение = 0.3209303688221005
# Стандартное ошибка = 0.0453864080165614
# Минимальное значение = 0.0004907971714923897
# Максимальное значение = 1.266792173775084
# Размах = 1.2663013766035915
# Первый квартиль = 0.14582890384561406
# Третий квартиль = 0.5501543205622377
# Межквартильный размах = 0.4043254167166236
# Ассиметрия = 0.9975475654802538
# Куртоз = 0.3293702615720777
# Коэффициент вариации = 0.8229641078232024
# Сумма = 19.498442627770473
#
# Количество = 50
# Среднее значение = 1.0043570646926832
# Медиана = 0.7654924862370152
# Мода = 0.375896169596644
# Геометрическое среднее = 0.5389869714847784
# Дисперсия = 0.8535374051229485
# Стандартное отклонение = 0.9238708811965818
# Стандартное ошибка = 0.13065507300697884
# Минимальное значение = 0.002678452458783943
# Максимальное значение = 3.800562325600061
# Размах = 3.797883873141277
# Первый квартиль = 0.35522646031088934
# Третий квартиль = 1.2540750385357438
# Межквартильный размах = 0.8988485782248544
# Ассиметрия = 1.3650866356728946
# Куртоз = 1.406343189981107
# Коэффициент вариации = 0.9198629786900251
# Сумма = 50.21785323463416
#
# Количество = 50
# Среднее значение = 0.9165498257531026
# Медиана = 0.5987366590275562
# Мода = 0.050844076913831304
# Геометрическое среднее = 0.5049055705353638
# Дисперсия = 0.776996817186075
# Стандартное отклонение = 0.8814742294509097
# Стандартное ошибка = 0.12465928101718499
# Минимальное значение = 0.0067128397640142294
# Максимальное значение = 3.624682202341803
# Размах = 3.6179693625777887
# Первый квартиль = 0.22967034401048317
# Третий квартиль = 1.3520498586347853
# Межквартильный размах = 1.122379514624302
# Ассиметрия = 1.3161811717449483
# Куртоз = 1.3762979913901647
# Коэффициент вариации = 0.9617308352294188
# Сумма = 45.82749128765513
